# %% [markdown]
# This creates a bar chart race that demonstrates decadal population growth of few states in india selected at random

# %%
import pandas as pd #We import Pandas to read the excel file

# %%
import bar_chart_race as bcr #We import ar chart race to create the animated bar graph

# %%
Data_Frame = pd.read_excel (r'/Users/brpawankumar/Desktop/States_Population_Growth.xlsx') # We load excel sheet in the dataset for further processing

# %%
Data_Frame = Data_Frame.set_index('Date') #We set the date column as the index for the rows

# %%
bcr.bar_chart_race(df = Data_Frame, title = "Population Growth")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="952" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
